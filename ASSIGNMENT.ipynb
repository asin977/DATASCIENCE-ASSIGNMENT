# %%
#                   Assignment on Python for Data Science

# %%
#                                                  Do the following operation on Iris dataset:
# 1. Read the dataset to the python environment.
# 2. Display the columns in the dataset.
# 3. Calculate the mean of each column of the dataset.
# 4. Check for the null values present in the dataset.
# 5. Perform meaningful visualizations using the dataset. Bring at least 3 meaningful visualizations.

# %%
# 1. Read the dataset to the python environment.

# %%
import pandas as pd

# Correct file path format
file_path = 'C:\\Users\\DELL\\OneDrive\\Desktop\\datascience\\iris.xls'

# Read the Excel file
dataset = pd.read_excel(file_path, engine='xlrd')

# Print the DataFrame
print(dataset)
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 2. Display the columns in the dataset.

# %%
print(dataset.columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
# 3. Calculate the mean of each column of the dataset.

# %%
import pandas as pd

# Correct file path
file_path = 'C:\\Users\\DELL\\OneDrive\\Desktop\\datascience\\iris.xls'

# Read the Excel file
df = pd.read_excel(file_path, engine='xlrd')

# Display the first few rows of the DataFrame
df.head()
# Out:
#     SL   SW   PL   PW Classification
# 0  5.1  3.5  1.4  0.2    Iris-setosa
# 1  4.9  3.0  1.4  0.2    Iris-setosa
# 2  4.7  3.2  1.3  0.2    Iris-setosa
# 3  4.6  3.1  1.5  0.2    Iris-setosa
# 4  5.0  3.6  1.4  0.2    Iris-setosa

# %%
df.SL.mean()
# Out:
# 5.843333333333334

# %%
df.SW.mean()
# Out:
# 3.0540000000000003

# %%
df.PL.mean()
# Out:
# 3.758666666666666

# %%
df.PW.mean()
# Out:
# 1.1986666666666668

# %%
dataset.mean
# Out:
# <bound method DataFrame.mean of       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]>

# %%
# Check for the null values present in the dataset.

# %%
null_values=dataset.isnull().sum()
print(null_values)
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#Perform meaningful visualizations using the dataset. Bring at least 3 meaningful visualizations.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'C:\\Users\\DELL\\OneDrive\\Desktop\\datascience\\iris.xls'
df = pd.read_excel(file_path, engine='xlrd')

# Create a pairplot with 'Classification' as hue
sns.pairplot(df, hue='Classification')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'C:\\Users\\DELL\\OneDrive\\Desktop\\datascience\\iris.xls'
df = pd.read_excel(file_path, engine='xlrd')

# Create a pairplot
sns.pairplot(df, hue='SL')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'C:\\Users\\DELL\\OneDrive\\Desktop\\datascience\\iris.xls'
df = pd.read_excel(file_path, engine='xlrd')

# Create a pairplot
sns.pairplot(df, hue='SW')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
file_path = 'C:\\Users\\DELL\\OneDrive\\Desktop\\datascience\\iris.xls'
df = pd.read_excel(file_path, engine='xlrd')

# Create a pairplot
sns.pairplot(df, hue='PW')
plt.show()

# %%
sns.pairplot(df,hue='PL')
plt.show()
